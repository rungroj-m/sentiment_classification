# %%
import autosklearn.classification
import csv
import json
import math
import matplotlib.pyplot as plt
import numpy as np
import re
import time
import warnings

from collections import defaultdict, OrderedDict
from myconfig import *
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics import confusion_matrix, classification_report, f1_score, precision_score, recall_score
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.ensemble import ExtraTreesClassifier

N_GRAM_LENGTH = 10
TOTAL_TYPE = 2

def read_raw_data():
    with open(DATA_SOURCE+"/dataset.csv", 'r',encoding='latin1') as csvfile:
        global total_document
        reader = csv.DictReader(csvfile)
        for row in reader:
            if row['project'] == project_name:
                comment_summary[total_document] = dict()
                comment_summary[total_document]['type'] = int(row['oracle'])
                comment_summary[total_document]['comment'] = row['text']
                total_document += 1

def file_len(fname):
    with open(fname) as f:
        for i, l in enumerate(f):
            pass
    return i + 1   

#read data from n_gram
def read_n_gram():
    n_gram_id = 0
    total_n_gram = file_len(DATA_SOURCE+"/importance_features/"+project_name+'_'+oracle+'_n_gram_filter')
    with open(DATA_SOURCE+"/importance_features/"+project_name+'_'+oracle+"_n_gram_filter") as csvfile:
        reader = csv.reader(csvfile, delimiter='\t', quotechar='|')
        for row in reader:
            words = row[5].strip()
            term = tuple(row[5].strip().split(' '))
            if term not in summary:
                summary[term] = dict()
            summary[term] = {'id':n_gram_id,'len':row[1],'gtf':row[2],'df':row[3],'sdf':row[4], 'term':row[5]}
            weight1 = total_document / int(row[4])
            summary[term]['score'] = math.log10(weight1) * int(row[2])
            score[n_gram_id] =  math.log10(weight1) * int(row[2])
            n_grams[n_gram_id] = term
            n_gram_id += 1

def top_score_vector():
    percent = int(len(score) * 100 / 100)
    top_vector.extend(sorted(score,key=score.get,reverse=True)[:percent])
#     print("top_vector",len(top_vector))

def n_gram_split():
    for comment_index in comment_summary:
        comment = comment_summary[comment_index]['comment']
        comment_summary[comment_index]['vector'] = dict()
        comment_post_process = re.sub("\s+"," ",re.sub(r"[^A-Za-z0-9]+"," ",comment.replace("\t"," ").replace("\r\n"," ").lower())).split(" ")
        for i in range(len(comment_post_process)):
            for j in range(i,min(i+N_GRAM_LENGTH+1,len(comment_post_process))):
                if(tuple(comment_post_process[i:j+1]) in summary):
                    if(summary[tuple(comment_post_process[i:j+1])]['id'] in top_vector):
                        if summary[tuple(comment_post_process[i:j+1])]['id'] in comment_summary[comment_index]['vector']:
                            comment_summary[comment_index]['vector'][summary[tuple(comment_post_process[i:j+1])]['id']] += 1
                        else: 
                            comment_summary[comment_index]['vector'][summary[tuple(comment_post_process[i:j+1])]['id']] = 1

def vector_idf():
    for i in comment_summary:
         for v in comment_summary[i]['vector']:
            comment_summary[i]['vector'][v] *= score[v]

for project_name in ["stackoverflow","jira","appreviews"]:
    for oracle in ["1","0","-1"]:
        if project_name == "jira" and oracle == "0":
            continue
        summary = dict()
        total_n_gram = 0
        total_document = 0
        score = dict()
        comment_summary = dict()
        top_vector = list()
        n_grams = dict()
        read_raw_data()
        read_n_gram()
        top_score_vector()
        n_gram_split()

        X = []
        y = []
        for comment_index in comment_summary:
            vector = [0] * len(top_vector)
            for vector_index in comment_summary[comment_index]['vector']:
                vector[top_vector.index(vector_index)] = comment_summary[comment_index]['vector'][vector_index]
            X.append(vector)
            y.append(comment_summary[comment_index]['type'])
            
        np_X = np.asarray(X)
        np_y = np.asarray(y)

        # forest = ExtraTreesClassifier(n_estimators=250, random_state=0)
        forest = RandomForestClassifier(n_estimators=10,random_state=1)

        forest.fit(np_X, np_y)
        importances = forest.feature_importances_
        std = np.std([tree.feature_importances_ for tree in forest.estimators_],
                     axis=0)
        indices = np.argsort(importances)[::-1]

        # Print the feature ranking
#         print("Feature ranking:")

        print_until = 1000
        runner = 0
        for f in range(np_X.shape[1]):
            if runner >= print_until:
                break
            symbol = "+"
            if oracle == "0":
                symbol = "N"
            elif oracle == "-1":
                symbol = "-"
            print("%s\t%s\t%d\t%s" % (project_name,symbol,f + 1,  n_grams[indices[f]]))
            runner += 1
# Out:
# stackoverflow	+	1	('onto',)
# stackoverflow	+	2	('option',)
# stackoverflow	+	3	('have',)
# stackoverflow	+	4	('way', 'to')
# stackoverflow	+	5	('than',)
# stackoverflow	+	6	('bit', 'of')
# stackoverflow	+	7	('design',)
# stackoverflow	+	8	('earlier',)
# stackoverflow	+	9	('still',)
# stackoverflow	+	10	('help', 'you')
# stackoverflow	+	11	('library',)
# stackoverflow	+	12	('part',)
# stackoverflow	+	13	('optimized',)
# stackoverflow	+	14	('less',)
# stackoverflow	+	15	('run', 'time')
# stackoverflow	+	16	('classes',)
# stackoverflow	+	17	('memory',)
# stackoverflow	+	18	('run',)
# stackoverflow	+	19	('like',)
# stackoverflow	+	20	('impact',)
# stackoverflow	+	21	('looking', 'for')
# stackoverflow	+	22	('better',)
# stackoverflow	+	23	('put',)
# stackoverflow	+	24	('databases', 'are')
# stackoverflow	+	25	('are',)
# stackoverflow	+	26	('jsf',)
# stackoverflow	+	27	('working',)
# stackoverflow	+	28	('code', 'fragment', 'to')
# stackoverflow	+	29	('java', 'is')
# stackoverflow	+	30	('json',)
# stackoverflow	+	31	('now',)
# stackoverflow	+	32	('only',)
# stackoverflow	+	33	('quite',)
# stackoverflow	+	34	('right',)
# stackoverflow	+	35	('far',)
# stackoverflow	+	36	('useful',)
# stackoverflow	+	37	('very',)
# stackoverflow	+	38	('other',)
# stackoverflow	+	39	('application',)
# stackoverflow	+	40	('might',)
# stackoverflow	+	41	('fast',)
# stackoverflow	+	42	('ok',)
# stackoverflow	+	43	('many',)
# stackoverflow	+	44	('help',)
# stackoverflow	+	45	('efficient',)
# stackoverflow	+	46	('lot',)
# stackoverflow	+	47	('done',)
# stackoverflow	+	48	('any',)
# stackoverflow	+	49	('but',)
# stackoverflow	+	50	('a', 'solution')
# stackoverflow	+	51	('or',)
# stackoverflow	+	52	('s', 'a', 'good')
# stackoverflow	+	53	('does',)
# stackoverflow	+	54	('structure',)
# stackoverflow	+	55	('you',)
# stackoverflow	+	56	('worry',)
# stackoverflow	+	57	('manually',)
# stackoverflow	+	58	('too',)
# stackoverflow	+	59	('was',)
# stackoverflow	+	60	('web',)
# stackoverflow	+	61	('will',)
# stackoverflow	+	62	('test',)
# stackoverflow	+	63	('api',)
# stackoverflow	+	64	('solution', 'is')
# stackoverflow	+	65	('prove',)
# stackoverflow	+	66	('method',)
# stackoverflow	+	67	('day',)
# stackoverflow	+	68	('parse', 'the')
# stackoverflow	+	69	('can',)
# stackoverflow	+	70	('array',)
# stackoverflow	+	71	('these',)
# stackoverflow	+	72	('solution',)
# stackoverflow	+	73	('for', 'me')
# stackoverflow	+	74	('production',)
# stackoverflow	+	75	('would',)
# stackoverflow	+	76	('but', 'i')
# stackoverflow	+	77	('object',)
# stackoverflow	+	78	('this', 'works')
# stackoverflow	+	79	('not',)
# stackoverflow	+	80	('works',)
# stackoverflow	+	81	('to', 'this')
# stackoverflow	+	82	('but', 'this')
# stackoverflow	+	83	('need',)
# stackoverflow	+	84	('types',)
# stackoverflow	+	85	('out',)
# stackoverflow	+	86	('solution', 'to')
# stackoverflow	+	87	('be', 'a')
# stackoverflow	+	88	('useful', 'for')
# stackoverflow	+	89	('think',)
# stackoverflow	+	90	('own',)
# stackoverflow	+	91	('there', 'is', 'no')
# stackoverflow	+	92	('this',)
# stackoverflow	+	93	('be',)
# stackoverflow	+	94	('you', 'with')
# stackoverflow	+	95	('just',)
# stackoverflow	+	96	('cases',)
# stackoverflow	+	97	('space',)
# stackoverflow	+	98	('problem',)
# stackoverflow	+	99	('there',)
# stackoverflow	+	100	('at',)
# stackoverflow	+	101	('in', 'your')
# stackoverflow	+	102	('you', 'are')
# stackoverflow	+	103	('and', 'the')
# stackoverflow	+	104	('way',)
# stackoverflow	+	105	('java',)
# stackoverflow	+	106	('as',)
# stackoverflow	+	107	('all',)
# stackoverflow	+	108	('path',)
# stackoverflow	+	109	('should',)
# stackoverflow	+	110	('solve',)
# stackoverflow	+	111	('with',)
# stackoverflow	+	112	('well',)
# stackoverflow	+	113	('also',)
# stackoverflow	+	114	('much',)
# stackoverflow	+	115	('work',)
# stackoverflow	+	116	('is', 'the')
# stackoverflow	+	117	('several',)
# stackoverflow	+	118	('more', 'efficient', 'to')
# stackoverflow	+	119	('fine',)
# stackoverflow	+	120	('correct',)
# stackoverflow	+	121	('built',)
# stackoverflow	+	122	('was', 'working')
# stackoverflow	+	123	('how',)
# stackoverflow	+	124	('the', 'code', 'fragment')
# stackoverflow	+	125	('helps',)
# stackoverflow	+	126	('the',)
# stackoverflow	+	127	('since',)
# stackoverflow	+	128	('to', 'the')
# stackoverflow	+	129	('from', 'the')
# stackoverflow	+	130	('code', 'fragment', 'is')
# stackoverflow	+	131	('on',)
# stackoverflow	+	132	('will', 'be')
# stackoverflow	+	133	('for', 'the')
# stackoverflow	+	134	('helpful',)
# stackoverflow	+	135	('resource',)
# stackoverflow	+	136	('for', 'example')
# stackoverflow	+	137	('takes',)
# stackoverflow	+	138	('s',)
# stackoverflow	+	139	('write',)
# stackoverflow	+	140	('re',)
# stackoverflow	+	141	('the', 'good')
# stackoverflow	+	142	('provides', 'the')
# stackoverflow	+	143	('if', 'you', 'are')
# stackoverflow	+	144	('would', 'be')
# stackoverflow	+	145	('file', 'name', 'that')
# stackoverflow	+	146	('this', 'is')
# stackoverflow	+	147	('uses',)
# stackoverflow	+	148	('specific',)
# stackoverflow	+	149	('using',)
# stackoverflow	+	150	('use',)
# stackoverflow	+	151	('here',)
# stackoverflow	+	152	('a', 'good', 'example')
# stackoverflow	+	153	('me',)
# stackoverflow	+	154	('example', 'the')
# stackoverflow	+	155	('good', 'example')
# stackoverflow	+	156	('configuration',)
# stackoverflow	+	157	('the', 'file')
# stackoverflow	+	158	('more',)
# stackoverflow	+	159	('each',)
# stackoverflow	+	160	('testing',)
# stackoverflow	+	161	('heap',)
# stackoverflow	+	162	('almost',)
# stackoverflow	+	163	('ve',)
# stackoverflow	+	164	('code',)
# stackoverflow	+	165	('should', 'be')
# stackoverflow	+	166	('api', 'name')
# stackoverflow	+	167	('file', 'name')
# stackoverflow	+	168	('of',)
# stackoverflow	+	169	('of', 'the')
# stackoverflow	+	170	('even',)
# stackoverflow	+	171	('i', 'finally')
# stackoverflow	+	172	('tasks',)
# stackoverflow	+	173	('the', 'list')
# stackoverflow	+	174	('file',)
# stackoverflow	+	175	('do',)
# stackoverflow	+	176	('its',)
# stackoverflow	+	177	('finally',)
# stackoverflow	+	178	('you', 'can')
# stackoverflow	+	179	('query',)
# stackoverflow	+	180	('both',)
# stackoverflow	+	181	('5',)
# stackoverflow	+	182	('a', 'good')
# stackoverflow	+	183	('using', 'the')
# stackoverflow	+	184	('most',)
# stackoverflow	+	185	('solved',)
# stackoverflow	+	186	('your',)
# stackoverflow	+	187	('the', 'simplest', 'solution')
# stackoverflow	+	188	('my',)
# stackoverflow	+	189	('and', 'it')
# stackoverflow	+	190	('it', 'faster')
# stackoverflow	+	191	('from',)
# stackoverflow	+	192	('can', 'be')
# stackoverflow	+	193	('s', 'the')
# stackoverflow	+	194	('we',)
# stackoverflow	+	195	('can', 'be', 'used')
# stackoverflow	+	196	('it', 's')
# stackoverflow	+	197	('able', 'to')
# stackoverflow	+	198	('and',)
# stackoverflow	+	199	('what',)
# stackoverflow	+	200	('read',)
# stackoverflow	+	201	('there', 'is')
# stackoverflow	+	202	('time',)
# stackoverflow	+	203	('with', 'the')
# stackoverflow	+	204	('number', 'of')
# stackoverflow	+	205	('currently',)
# stackoverflow	+	206	('provides',)
# stackoverflow	+	207	('no',)
# stackoverflow	+	208	('it', 'will')
# stackoverflow	+	209	('about',)
# stackoverflow	+	210	('by',)
# stackoverflow	+	211	('it', 'works')
# stackoverflow	+	212	('good',)
# stackoverflow	+	213	('works', 'fine')
# stackoverflow	+	214	('with', 'a', 'good')
# stackoverflow	+	215	('which',)
# stackoverflow	+	216	('best',)
# stackoverflow	+	217	('s', 'a')
# stackoverflow	+	218	('is',)
# stackoverflow	+	219	('to', 'use')
# stackoverflow	+	220	('that', 'you')
# stackoverflow	+	221	('set',)
# stackoverflow	+	222	('use', 'of')
# stackoverflow	+	223	('a', 'file')
# stackoverflow	+	224	('the', 'path')
# stackoverflow	+	225	('is', 'a')
# stackoverflow	+	226	('that',)
# stackoverflow	+	227	('in', 'the')
# stackoverflow	+	228	('to', 'do')
# stackoverflow	+	229	('if',)
# stackoverflow	+	230	('there', 'are')
# stackoverflow	+	231	('you', 'can', 'do')
# stackoverflow	+	232	('in',)
# stackoverflow	+	233	('exception',)
# stackoverflow	+	234	('it',)
# stackoverflow	+	235	('the', 'following')
# stackoverflow	+	236	('lot', 'of')
# stackoverflow	+	237	('so',)
# stackoverflow	+	238	('your', 'code')
# stackoverflow	+	239	('when',)
# stackoverflow	+	240	('within',)
# stackoverflow	+	241	('can', 'make')
# stackoverflow	+	242	('a',)
# stackoverflow	+	243	('time', 'should', 'be')
# stackoverflow	+	244	('code', 'fragment')
# stackoverflow	+	245	('it', 'is')
# stackoverflow	+	246	('print',)
# stackoverflow	+	247	('i', 'was')
# stackoverflow	+	248	('is', 'the', 'best')
# stackoverflow	+	249	('for',)
# stackoverflow	+	250	('data',)
# stackoverflow	+	251	('flexibility', 'and')
# stackoverflow	+	252	('api', 'name', 'it')
# stackoverflow	+	253	('they',)
# stackoverflow	+	254	('i', 'have')
# stackoverflow	+	255	('to', 'be')
# stackoverflow	+	256	('and', 'it', 'works')
# stackoverflow	+	257	('i', 'think')
# stackoverflow	+	258	('an',)
# stackoverflow	+	259	('to',)
# stackoverflow	+	260	('one',)
# stackoverflow	+	261	('i', 'can')
# stackoverflow	+	262	('n', 't')
# stackoverflow	+	263	('to', 'convert')
# stackoverflow	+	264	('name',)
# stackoverflow	+	265	('a', 'lot')
# stackoverflow	+	266	('the', 'best')
# stackoverflow	+	267	('do', 'n', 't', 'need', 'to')
# stackoverflow	+	268	('if', 'you')
# stackoverflow	+	269	('i',)
# stackoverflow	+	270	('performance',)
# stackoverflow	+	271	('and', 'you')
# stackoverflow	+	272	('check',)
# stackoverflow	+	273	('by', 'using')
# stackoverflow	+	274	('the', 'simplest')
# stackoverflow	+	275	('example',)
# stackoverflow	+	276	('in', 'a')
# stackoverflow	+	277	('you', 'can', 'use')
# stackoverflow	+	278	('case',)
# stackoverflow	+	279	('by', 'the')
# stackoverflow	N	1	('received',)
# stackoverflow	N	2	('everyone',)
# stackoverflow	N	3	('the', 'customer')
# stackoverflow	N	4	('local',)
# stackoverflow	N	5	('selenium',)
# stackoverflow	N	6	('the', 'console', 'tells', 'me')
# stackoverflow	N	7	('20',)
# stackoverflow	N	8	('region', 's', 'wall', 'clock', 'time')
# stackoverflow	N	9	('technical',)
# stackoverflow	N	10	('hc',)
# stackoverflow	N	11	('against',)
# stackoverflow	N	12	('appointments',)
# stackoverflow	N	13	('ideally',)
# stackoverflow	N	14	('object', 'in')
# stackoverflow	N	15	('warning',)
# stackoverflow	N	16	('renderer',)
# stackoverflow	N	17	('of', 'objects')
# stackoverflow	N	18	('host',)
# stackoverflow	N	19	('direct',)
# stackoverflow	N	20	('provided',)
# stackoverflow	N	21	('decorating',)
# stackoverflow	N	22	('newsletter',)
# stackoverflow	N	23	('sends',)
# stackoverflow	N	24	('graph',)
# stackoverflow	N	25	('println',)
# stackoverflow	N	26	('when', 'you', 'get')
# stackoverflow	N	27	('templates',)
# stackoverflow	N	28	('matching',)
# stackoverflow	N	29	('had',)
# stackoverflow	N	30	('book', 'time')
# stackoverflow	N	31	('records',)
# stackoverflow	N	32	('represents',)
# stackoverflow	N	33	('computer', 's')
# stackoverflow	N	34	('ec', 'cc', 'pt')
# stackoverflow	N	35	('made',)
# stackoverflow	N	36	('float',)
# stackoverflow	N	37	('token',)
# stackoverflow	N	38	('again',)
# stackoverflow	N	39	('call', 'api', 'name')
# stackoverflow	N	40	('fields',)
# stackoverflow	N	41	('music',)
# stackoverflow	N	42	('directory',)
# stackoverflow	N	43	('iis',)
# stackoverflow	N	44	('march', '30', '2010', '01', '00', 'utc')
# stackoverflow	N	45	('oracle', 'function')
# stackoverflow	N	46	('survey',)
# stackoverflow	N	47	('customer',)
# stackoverflow	N	48	('the', 'callback')
# stackoverflow	N	49	('projects',)
# stackoverflow	N	50	('limitation',)
# stackoverflow	N	51	('back',)
# stackoverflow	N	52	('sent',)
# stackoverflow	N	53	('yourself',)
# stackoverflow	N	54	('those',)
# stackoverflow	N	55	('red',)
# stackoverflow	N	56	('to', 'do', 'is', 'get')
# stackoverflow	N	57	('appointment',)
# stackoverflow	N	58	('reason',)
# stackoverflow	N	59	('bit',)
# stackoverflow	N	60	('i', 'tried', 'to')
# stackoverflow	N	61	('lines', 'of')
# stackoverflow	N	62	('ready',)
# stackoverflow	N	63	('locale',)
# stackoverflow	N	64	('mode',)
# stackoverflow	N	65	('moment',)
# stackoverflow	N	66	('code', 'i')
# stackoverflow	N	67	('to', 'code', 'fragment')
# stackoverflow	N	68	('know', 'if')
# stackoverflow	N	69	('is', 'used')
# stackoverflow	N	70	('having',)
# stackoverflow	N	71	('hints',)
# stackoverflow	N	72	('the', 'lines')
# stackoverflow	N	73	('code', 'you')
# stackoverflow	N	74	('container', 'that')
# stackoverflow	N	75	('previous',)
# stackoverflow	N	76	('solve',)
# stackoverflow	N	77	('00',)
# stackoverflow	N	78	('download',)
# stackoverflow	N	79	('suggest', 'using')
# stackoverflow	N	80	('price',)
# stackoverflow	N	81	('server',)
# stackoverflow	N	82	('the', 'code', 'to')
# stackoverflow	N	83	('bytes',)
# stackoverflow	N	84	('code', 'that')
# stackoverflow	N	85	('found',)
# stackoverflow	N	86	('description',)
# stackoverflow	N	87	('three',)
# stackoverflow	N	88	('then', 'you')
# stackoverflow	N	89	('an', 'alternative')
# stackoverflow	N	90	('x',)
# stackoverflow	N	91	('cest',)
# stackoverflow	N	92	('example',)
# stackoverflow	N	93	('ascii',)
# stackoverflow	N	94	('adapter',)
# stackoverflow	N	95	('march',)
# stackoverflow	N	96	('compile',)
# stackoverflow	N	97	('utc',)
# stackoverflow	N	98	('font',)
# stackoverflow	N	99	('instead',)
# stackoverflow	N	100	('is', 'there', 'any')
# stackoverflow	N	101	('came',)
# stackoverflow	N	102	('become',)
# stackoverflow	N	103	('style',)
# stackoverflow	N	104	('i', 'tried')
# stackoverflow	N	105	('parse',)
# stackoverflow	N	106	('jaxb',)
# stackoverflow	N	107	('chat',)
# stackoverflow	N	108	('still',)
# stackoverflow	N	109	('59',)
# stackoverflow	N	110	('home',)
# stackoverflow	N	111	('fact',)
# stackoverflow	N	112	('tag',)
# stackoverflow	N	113	('per', 'the')
# stackoverflow	N	114	('of', 'a')
# stackoverflow	N	115	('database',)
# stackoverflow	N	116	('fails',)
# stackoverflow	N	117	('see', 'that')
# stackoverflow	N	118	('off',)
# stackoverflow	N	119	('standard',)
# stackoverflow	N	120	('non', 'parallel')
# stackoverflow	N	121	('i', 'get')
# stackoverflow	N	122	('file', 'file', 'name')
# stackoverflow	N	123	('case',)
# stackoverflow	N	124	('to', 'convert')
# stackoverflow	N	125	('words',)
# stackoverflow	N	126	('synchronized',)
# stackoverflow	N	127	('maybe', 'you')
# stackoverflow	N	128	('statement',)
# stackoverflow	N	129	('count',)
# stackoverflow	N	130	('otherwise',)
# stackoverflow	N	131	('enable',)
# stackoverflow	N	132	('appended',)
# stackoverflow	N	133	('tried', 'using')
# stackoverflow	N	134	('choose',)
# stackoverflow	N	135	('questions',)
# stackoverflow	N	136	('gradle',)
# stackoverflow	N	137	('accepts',)
# stackoverflow	N	138	('file', 'name', 'created', 'by')
# stackoverflow	N	139	('blockingqueue',)
# stackoverflow	N	140	('string', 'object')
# stackoverflow	N	141	('callbacks',)
# stackoverflow	N	142	('any', 'other')
# stackoverflow	N	143	('march', '30', '2010')
# stackoverflow	N	144	('also', 'have')
# stackoverflow	N	145	('tostring',)
# stackoverflow	N	146	('trying', 'to', 'make')
# stackoverflow	N	147	('lot', 'of')
# stackoverflow	N	148	('binaries',)
# stackoverflow	N	149	('want', 'to')
# stackoverflow	N	150	('text', 'file')
# stackoverflow	N	151	('entities',)
# stackoverflow	N	152	('need', 'the')
# stackoverflow	N	153	('second',)
# stackoverflow	N	154	('types',)
# stackoverflow	N	155	('explained',)
# stackoverflow	N	156	('true',)
# stackoverflow	N	157	('progress',)
# stackoverflow	N	158	('write', 'a')
# stackoverflow	N	159	('apache',)
# stackoverflow	N	160	('heap',)
# stackoverflow	N	161	('click', 'on')
# stackoverflow	N	162	('reader', 'is')
# stackoverflow	N	163	('to', 'the', 'method')
# stackoverflow	N	164	('comments',)
# stackoverflow	N	165	('understood',)
# stackoverflow	N	166	('can', 'i')
# stackoverflow	N	167	('because', 'i')
# stackoverflow	N	168	('camel', 'jaxb')
# stackoverflow	N	169	('says',)
# stackoverflow	N	170	('odata',)
# stackoverflow	N	171	('pointer',)
# stackoverflow	N	172	('its',)
# stackoverflow	N	173	('add', 'the')
# stackoverflow	N	174	('classes', 'like')
# stackoverflow	N	175	('export',)
# stackoverflow	N	176	('march', '30', '2010', '01')
# stackoverflow	N	177	('trying', 'to')
# stackoverflow	N	178	('this', 'to')
# stackoverflow	N	179	('group',)
# stackoverflow	N	180	('ve', 'added')
# stackoverflow	N	181	('parameter',)
# stackoverflow	N	182	('which', 'is')
# stackoverflow	N	183	('jdk',)
# stackoverflow	N	184	('rules',)
# stackoverflow	N	185	('term',)
# stackoverflow	N	186	('2nd',)
# stackoverflow	N	187	('dependencies',)
# stackoverflow	N	188	('website',)
# stackoverflow	N	189	('plug',)
# stackoverflow	N	190	('if', 'you', 'can')
# stackoverflow	N	191	('labels',)
# stackoverflow	N	192	('blocking',)
# stackoverflow	N	193	('appended', 'to')
# stackoverflow	N	194	('problem',)
# stackoverflow	N	195	('going',)
# stackoverflow	N	196	('appcompat',)
# stackoverflow	N	197	('jsonarray',)
# stackoverflow	N	198	('maps',)
# stackoverflow	N	199	('e',)
# stackoverflow	N	200	('the', 'repository')
# stackoverflow	N	201	('connect',)
# stackoverflow	N	202	('read',)
# stackoverflow	N	203	('parallel',)
# stackoverflow	N	204	('by',)
# stackoverflow	N	205	('simple',)
# stackoverflow	N	206	('works',)
# stackoverflow	N	207	('to', 'have')
# stackoverflow	N	208	('add', 'this')
# stackoverflow	N	209	('hence', 'the')
# stackoverflow	N	210	('if', 'there')
# stackoverflow	N	211	('notification',)
# stackoverflow	N	212	('to', 'create', 'the')
# stackoverflow	N	213	('the', 'regex')
# stackoverflow	N	214	('constraints',)
# stackoverflow	N	215	('device',)
# stackoverflow	N	216	('meant',)
# stackoverflow	N	217	('to', 'do', 'it')
# stackoverflow	N	218	('sample',)
# stackoverflow	N	219	('the', 'issue')
# stackoverflow	N	220	('and', 'what', 'is')
# stackoverflow	N	221	('a', 'couple')
# stackoverflow	N	222	('enter',)
# stackoverflow	N	223	('times',)
# stackoverflow	N	224	('quick', 'fix')
# stackoverflow	N	225	('requested',)
# stackoverflow	N	226	('needs',)
# stackoverflow	N	227	('you', 'should', 'always')
# stackoverflow	N	228	('waiting',)
# stackoverflow	N	229	('i', 'm', 'working')
# stackoverflow	N	230	('an', 'android')
# stackoverflow	N	231	('straight',)
# stackoverflow	N	232	('page',)
# stackoverflow	N	233	('window',)
# stackoverflow	N	234	('figure', 'out')
# stackoverflow	N	235	('operation',)
# stackoverflow	N	236	('i', 'changed', 'the')
# stackoverflow	N	237	('programmatically',)
# stackoverflow	N	238	('find', 'out')
# stackoverflow	N	239	('tomcat', '6')
# stackoverflow	N	240	('there', 'should')
# stackoverflow	N	241	('go',)
# stackoverflow	N	242	('in', 'the', 'above', 'code')
# stackoverflow	N	243	('consider', 'the', 'following')
# stackoverflow	N	244	('case', 'i')
# stackoverflow	N	245	('the', 'list')
# stackoverflow	N	246	('using', 'apache')
# stackoverflow	N	247	('modifying',)
# stackoverflow	N	248	('how', 'to', 'do')
# stackoverflow	N	249	('daylight',)
# stackoverflow	N	250	('of', 'data')
# stackoverflow	N	251	('parent',)
# stackoverflow	N	252	('be',)
# stackoverflow	N	253	('note', 'that')
# stackoverflow	N	254	('issue',)
# stackoverflow	N	255	('integer',)
# stackoverflow	N	256	('periodically',)
# stackoverflow	N	257	('for', 'a', 'java')
# stackoverflow	N	258	('you', 'can', 'create', 'the')
# stackoverflow	N	259	('given',)
# stackoverflow	N	260	('reference',)
# stackoverflow	N	261	('vbox',)
# stackoverflow	N	262	('were',)
# stackoverflow	N	263	('only',)
# stackoverflow	N	264	('is', 'of')
# stackoverflow	N	265	('though',)
# stackoverflow	N	266	('assuming', 'that')
# stackoverflow	N	267	('http',)
# stackoverflow	N	268	('in', 'your', 'code')
# stackoverflow	N	269	('out',)
# stackoverflow	N	270	('field',)
# stackoverflow	N	271	('main', 'thread')
# stackoverflow	N	272	('utf', '8')
# stackoverflow	N	273	('dash',)
# stackoverflow	N	274	('logs', 'and')
# stackoverflow	N	275	('takes',)
# stackoverflow	N	276	('included',)
# stackoverflow	N	277	('threads',)
# stackoverflow	N	278	('compile', 'time')
# stackoverflow	N	279	('environment',)
# stackoverflow	N	280	('systems',)
# stackoverflow	N	281	('oracle',)
# stackoverflow	N	282	('assume', 'that')
# stackoverflow	N	283	('fun',)
# stackoverflow	N	284	('in', 'main')
# stackoverflow	N	285	('fully',)
# stackoverflow	N	286	('yet',)
# stackoverflow	N	287	('assign',)
# stackoverflow	N	288	('maybe',)
# stackoverflow	N	289	('consider',)
# stackoverflow	N	290	('hours',)
# stackoverflow	N	291	('here', 'web', 'address')
# stackoverflow	N	292	('create', 'an')
# stackoverflow	N	293	('few',)
# stackoverflow	N	294	('chars',)
# stackoverflow	N	295	('information',)
# stackoverflow	N	296	('statements',)
# stackoverflow	N	297	('generate',)
# stackoverflow	N	298	('extra',)
# stackoverflow	N	299	('comparator',)
# stackoverflow	N	300	('point', 'to')
# stackoverflow	N	301	('is', 'to')
# stackoverflow	N	302	('i', 'm')
# stackoverflow	N	303	('to', 'make')
# stackoverflow	N	304	('submit', 'button')
# stackoverflow	N	305	('far',)
# stackoverflow	N	306	('websocket',)
# stackoverflow	N	307	('going', 'to')
# stackoverflow	N	308	('number',)
# stackoverflow	N	309	('jsp',)
# stackoverflow	N	310	('why', 'do')
# stackoverflow	N	311	('processed',)
# stackoverflow	N	312	('cms',)
# stackoverflow	N	313	('what', 'i', 'have')
# stackoverflow	N	314	('an', 'array')
# stackoverflow	N	315	('state',)
# stackoverflow	N	316	('the', 'code', 'is')
# stackoverflow	N	317	('document',)
# stackoverflow	N	318	('is', 'the', 'code')
# stackoverflow	N	319	('jsf',)
# stackoverflow	N	320	('otherwise', 'you')
# stackoverflow	N	321	('outside',)
# stackoverflow	N	322	('press', 'enter')
# stackoverflow	N	323	('is', 'as')
# stackoverflow	N	324	('number', 'of')
# stackoverflow	N	325	('tool',)
# stackoverflow	N	326	('a', 'code', 'fragment')
# stackoverflow	N	327	('is',)
# stackoverflow	N	328	('seems',)
# stackoverflow	N	329	('midnight',)
# stackoverflow	N	330	('hierarchy',)
# stackoverflow	N	331	('scroll',)
# stackoverflow	N	332	('multiple',)
# stackoverflow	N	333	('possible', 'to')
# stackoverflow	N	334	('python',)
# stackoverflow	N	335	('generated',)
# stackoverflow	N	336	('int',)
# stackoverflow	N	337	('parse', 'the')
# stackoverflow	N	338	('quite',)
# stackoverflow	N	339	('a', 'certain')
# stackoverflow	N	340	('forward',)
# stackoverflow	N	341	('of', 'string')
# stackoverflow	N	342	('mock',)
# stackoverflow	N	343	('set', 'the')
# stackoverflow	N	344	('the', 'batch', 'file')
# stackoverflow	N	345	('n', 't', 'use')
# stackoverflow	N	346	('refer',)
# stackoverflow	N	347	('signature',)
# stackoverflow	N	348	('some', 'of', 'the')
# stackoverflow	N	349	('byte',)
# stackoverflow	N	350	('name', 'that')
# stackoverflow	N	351	('does', 'not')
# stackoverflow	N	352	('same',)
# stackoverflow	N	353	('all', 'you')
# stackoverflow	N	354	('caused', 'by')
# stackoverflow	N	355	('determine',)
# stackoverflow	N	356	('correct',)
# stackoverflow	N	357	('to', 'do', 'this')
# stackoverflow	N	358	('strings',)
# stackoverflow	N	359	('say', 'code', 'fragment', 'and')
# stackoverflow	N	360	('using', 'java')
# stackoverflow	N	361	('old',)
# stackoverflow	N	362	('controller',)
# stackoverflow	N	363	('sample1', 'sample2')
# stackoverflow	N	364	('be', 'a')
# stackoverflow	N	365	('configuration',)
# stackoverflow	N	366	('table',)
# stackoverflow	N	367	('utf',)
# stackoverflow	N	368	('description', 'of')
# stackoverflow	N	369	('syntax',)
# stackoverflow	N	370	('file', 'name', 'api')
# stackoverflow	N	371	('usually',)
# stackoverflow	N	372	('instantiation', 'through', 'jsf')
# stackoverflow	N	373	('a', 'bug')
# stackoverflow	N	374	('replaced', 'with', 'code', 'fragment')
# stackoverflow	N	375	('a', 'question')
# stackoverflow	N	376	('likely',)
# stackoverflow	N	377	('selects',)
# stackoverflow	N	378	('an', 'example', 'of', 'a')
# stackoverflow	N	379	('support',)
# stackoverflow	N	380	('that', 'we')
# stackoverflow	N	381	('objects',)
# stackoverflow	N	382	('assume',)
# stackoverflow	N	383	('avoid',)
# stackoverflow	N	384	('now',)
# stackoverflow	N	385	('property',)
# stackoverflow	N	386	('parser',)
# stackoverflow	N	387	('ensure',)
# stackoverflow	N	388	('post', 'request')
# stackoverflow	N	389	('over',)
# stackoverflow	N	390	('here', 'is', 'the')
# stackoverflow	N	391	('clients',)
# stackoverflow	N	392	('length', 'of')
# stackoverflow	N	393	('modified',)
# stackoverflow	N	394	('that', 'i', 'have')
# stackoverflow	N	395	('know', 'the')
# stackoverflow	N	396	('documentation',)
# stackoverflow	N	397	('someone',)
# stackoverflow	N	398	('close',)
# stackoverflow	N	399	('from', 'the')
# stackoverflow	N	400	('copy',)
# stackoverflow	N	401	('bean',)
# stackoverflow	N	402	('translated',)
# stackoverflow	N	403	('provide', 'a')
# stackoverflow	N	404	('batik',)
# stackoverflow	N	405	('append', 'mode')
# stackoverflow	N	406	('file', 'name', 'is')
# stackoverflow	N	407	('creates',)
# stackoverflow	N	408	('should', 'have')
# stackoverflow	N	409	('to', '2')
# stackoverflow	N	410	('post',)
# stackoverflow	N	411	('cells',)
# stackoverflow	N	412	('this', 'way')
# stackoverflow	N	413	('javascript',)
# stackoverflow	N	414	('to', 'have', 'a')
# stackoverflow	N	415	('dynamic',)
# stackoverflow	N	416	('file', 'name', 'code')
# stackoverflow	N	417	('you', 'are')
# stackoverflow	N	418	('of', 'file', 'name')
# stackoverflow	N	419	('any',)
# stackoverflow	N	420	('regular',)
# stackoverflow	N	421	('month',)
# stackoverflow	N	422	('desired',)
# stackoverflow	N	423	('you', 'can', 'create')
# stackoverflow	N	424	('manifest',)
# stackoverflow	N	425	('dependency',)
# stackoverflow	N	426	('command',)
# stackoverflow	N	427	('to', 'compile')
# stackoverflow	N	428	('when', 'you', 'have')
# stackoverflow	N	429	('it', 'is')
# stackoverflow	N	430	('name', 'number')
# stackoverflow	N	431	('jni',)
# stackoverflow	N	432	('separate',)
# stackoverflow	N	433	('create', 'an', 'object')
# stackoverflow	N	434	('some', 'of')
# stackoverflow	N	435	('bower',)
# stackoverflow	N	436	('batch', 'file')
# stackoverflow	N	437	('cglib',)
# stackoverflow	N	438	('pdf',)
# stackoverflow	N	439	('a', 'library')
# stackoverflow	N	440	('socket',)
# stackoverflow	N	441	('a', 'java')
# stackoverflow	N	442	('if', 'i')
# stackoverflow	N	443	('core',)
# stackoverflow	N	444	('provide',)
# stackoverflow	N	445	('of', 'code')
# stackoverflow	N	446	('event',)
# stackoverflow	N	447	('android', 'app')
# stackoverflow	N	448	('code', 'fragment', 'on', 'the')
# stackoverflow	N	449	('they',)
# stackoverflow	N	450	('goal',)
# stackoverflow	N	451	('in', 'the', 'code')
# stackoverflow	N	452	('examples',)
# stackoverflow	N	453	('for', 'the', 'code', 'fragment')
# stackoverflow	N	454	('there', 'are')
# stackoverflow	N	455	('party',)
# stackoverflow	N	456	('get', 'the', 'following')
# stackoverflow	N	457	('to', 'solve')
# stackoverflow	N	458	('suggested',)
# stackoverflow	N	459	('4',)
# stackoverflow	N	460	('ide',)
# stackoverflow	N	461	('for', 'your')
# stackoverflow	N	462	('needed',)
# stackoverflow	N	463	('created',)
# stackoverflow	N	464	('compare',)
# stackoverflow	N	465	('jackson',)
# stackoverflow	N	466	('you', 'see')
# stackoverflow	N	467	('spring', 'is')
# stackoverflow	N	468	('steps',)
# stackoverflow	N	469	('wrong',)
# stackoverflow	N	470	('more', 'than', '5')
# stackoverflow	N	471	('configuration', 'file')
# stackoverflow	N	472	('problem', 'i')
# stackoverflow	N	473	('connection',)
# stackoverflow	N	474	('versus',)
# stackoverflow	N	475	('thanks',)
# stackoverflow	N	476	('to', 'handle')
# stackoverflow	N	477	('jar', 'file')
# stackoverflow	N	478	('notes',)
# stackoverflow	N	479	('interesting',)
# stackoverflow	N	480	('nothing',)
# stackoverflow	N	481	('cause',)
# stackoverflow	N	482	('api', 'key')
# stackoverflow	N	483	('final',)
# stackoverflow	N	484	('my',)
# stackoverflow	N	485	('so', 'you', 'can')
# stackoverflow	N	486	('or', 'a')
# stackoverflow	N	487	('a', 'string')
# stackoverflow	N	488	('is', 'actually')
# stackoverflow	N	489	('have', 'this')
# stackoverflow	N	490	('guide',)
# stackoverflow	N	491	('script',)
# stackoverflow	N	492	('os',)
# stackoverflow	N	493	('last',)
# stackoverflow	N	494	('and', 'not')
# stackoverflow	N	495	('project',)
# stackoverflow	N	496	('contain',)
# stackoverflow	N	497	('loop', 'and')
# stackoverflow	N	498	('your', 'api', 'name')
# stackoverflow	N	499	('saves', 'you')
# stackoverflow	N	500	('know', 'what')
# stackoverflow	N	501	('static',)
# stackoverflow	N	502	('js',)
# stackoverflow	N	503	('context',)
# stackoverflow	N	504	('something',)
# stackoverflow	N	505	('modified', 'the')
# stackoverflow	N	506	('will',)
# stackoverflow	N	507	('regex',)
# stackoverflow	N	508	('lib',)
# stackoverflow	N	509	('platform',)
# stackoverflow	N	510	('public',)
# stackoverflow	N	511	('comment',)
# stackoverflow	N	512	('resource',)
# stackoverflow	N	513	('to', 'use', 'the')
# stackoverflow	N	514	('question',)
# stackoverflow	N	515	('2013',)
# stackoverflow	N	516	('if', 'you', 'add')
# stackoverflow	N	517	('recommend', 'that')
# stackoverflow	N	518	('code', 'fragment', 'with', 'a')
# stackoverflow	N	519	('binary',)
# stackoverflow	N	520	('running', 'code', 'fragment')
# stackoverflow	N	521	('in', 'my')
# stackoverflow	N	522	('jpa',)
# stackoverflow	N	523	('code', 'fragment', 'code')
# stackoverflow	N	524	('run',)
# stackoverflow	N	525	('means', 'that')
# stackoverflow	N	526	('and', 'an')
# stackoverflow	N	527	('the', 'music')
# stackoverflow	N	528	('test1',)
# stackoverflow	N	529	('existing',)
# stackoverflow	N	530	('special',)
# stackoverflow	N	531	('behaviour',)
# stackoverflow	N	532	('flags',)
# stackoverflow	N	533	('a', 'sample')
# stackoverflow	N	534	('i', 'can', 'get')
# stackoverflow	N	535	('be', 'referenced')
# stackoverflow	N	536	('implement',)
# stackoverflow	N	537	('when', 'i', 'run', 'this')
# stackoverflow	N	538	('thread', '2')
# stackoverflow	N	539	('instead', 'of')
# stackoverflow	N	540	('collector',)
# stackoverflow	N	541	('scope',)
# stackoverflow	N	542	('two',)
# stackoverflow	N	543	('fix',)
# stackoverflow	N	544	('setting',)
# stackoverflow	N	545	('according', 'to')
# stackoverflow	N	546	('do', 'n', 't')
# stackoverflow	N	547	('session',)
# stackoverflow	N	548	('you', 'add')
# stackoverflow	N	549	('have', 'a', 'requirement', 'to')
# stackoverflow	N	550	('exception',)
# stackoverflow	N	551	('bug',)
# stackoverflow	N	552	('decide',)
# stackoverflow	N	553	('of', 'our')
# stackoverflow	N	554	('implement', 'a')
# stackoverflow	N	555	('days',)
# stackoverflow	N	556	('list',)
# stackoverflow	N	557	('are', 'they')
# stackoverflow	N	558	('inside',)
# stackoverflow	N	559	('to', 'my')
# stackoverflow	N	560	('finished',)
# stackoverflow	N	561	('the', 'way')
# stackoverflow	N	562	('a', 'solution')
# stackoverflow	N	563	('you', 'do', 'n', 't', 'need')
# stackoverflow	N	564	('insert',)
# stackoverflow	N	565	('year',)
# stackoverflow	N	566	('any', 'better')
# stackoverflow	N	567	('linux',)
# stackoverflow	N	568	('give', 'it', 'a')
# stackoverflow	N	569	('worth',)
# stackoverflow	N	570	('container',)
# stackoverflow	N	571	('repository',)
# stackoverflow	N	572	('tutorial',)
# stackoverflow	N	573	('my', 'question')
# stackoverflow	N	574	('tree',)
# stackoverflow	N	575	('format',)
# stackoverflow	N	576	('api', 'name', 'file')
# stackoverflow	N	577	('or',)
# stackoverflow	N	578	('for', 'the')
# stackoverflow	N	579	('junit',)
# stackoverflow	N	580	('method', 'is')
# stackoverflow	N	581	('use', 'the', 'code', 'fragment')
# stackoverflow	N	582	('size',)
# stackoverflow	N	583	('control', 'panel')
# stackoverflow	N	584	('prints',)
# stackoverflow	N	585	('please',)
# stackoverflow	N	586	('sure',)
# stackoverflow	N	587	('quick',)
# stackoverflow	N	588	('code', 'fragment', 'i')
# stackoverflow	N	589	('issue', 'is')
# stackoverflow	N	590	('name', 'code')
# stackoverflow	N	591	('factory',)
# stackoverflow	N	592	('documentation', 'of')
# stackoverflow	N	593	('to', 'achieve')
# stackoverflow	N	594	('created', 'by')
# stackoverflow	N	595	('you', 'can', 'try', 'the')
# stackoverflow	N	596	('using', 'a', 'concurrent')
# stackoverflow	N	597	('message',)
# stackoverflow	N	598	('the', 'docs')
# stackoverflow	N	599	('come',)
# stackoverflow	N	600	('native',)
# stackoverflow	N	601	('construct',)
# stackoverflow	N	602	('uses',)
# stackoverflow	N	603	('tells',)
# stackoverflow	N	604	('extract',)
# stackoverflow	N	605	('1',)
# stackoverflow	N	606	('all', 'variables')
# stackoverflow	N	607	('code',)
# stackoverflow	N	608	('difference',)
# stackoverflow	N	609	('is', 'empty')
# stackoverflow	N	610	('look',)
# stackoverflow	N	611	('pair',)
# stackoverflow	N	612	('code', 'that', 'i')
# stackoverflow	N	613	('specify',)
# stackoverflow	N	614	('supply',)
# stackoverflow	N	615	('it', 'holds')
# stackoverflow	N	616	('here', 'is', 'the', 'file', 'name')
# stackoverflow	N	617	('should',)
# stackoverflow	N	618	('done',)
# stackoverflow	N	619	('helps',)
# stackoverflow	N	620	('shows', 'that')
# stackoverflow	N	621	('gc',)
# stackoverflow	N	622	('the', 'apache')
# stackoverflow	N	623	('it', 'as')
# stackoverflow	N	624	('more', 'than')
# stackoverflow	N	625	('line', 'is')
# stackoverflow	N	626	('code', 'fragment', 'to', 'get', 'the')
# stackoverflow	N	627	('started',)
# stackoverflow	N	628	('each',)
# stackoverflow	N	629	('control',)
# stackoverflow	N	630	('the', 'object')
# stackoverflow	N	631	('there', 'is', 'a')
# stackoverflow	N	632	('you', 'read')
# stackoverflow	N	633	('e', 'g', 'i')
# stackoverflow	N	634	('checks',)
# stackoverflow	N	635	('more',)
# stackoverflow	N	636	('n',)
# stackoverflow	N	637	('for', 'a')
# stackoverflow	N	638	('element',)
# stackoverflow	N	639	('fine',)
# stackoverflow	N	640	('copied',)
# stackoverflow	N	641	('for', 'any')
# stackoverflow	N	642	('whatever',)
# stackoverflow	N	643	('very',)
# stackoverflow	N	644	('a', 'few')
# stackoverflow	N	645	('vm',)
# stackoverflow	N	646	('content',)
# stackoverflow	N	647	('through', 'the')
# stackoverflow	N	648	('a', 'file', 'name')
# stackoverflow	N	649	('eclipse',)
# stackoverflow	N	650	('compiling',)
# stackoverflow	N	651	('details',)
# stackoverflow	N	652	('ago',)
# stackoverflow	N	653	('properties',)
# stackoverflow	N	654	('this', 'topic')
# stackoverflow	N	655	('give',)
# stackoverflow	N	656	('type', 'is')
# stackoverflow	N	657	('thinking',)
# stackoverflow	N	658	('longer',)
# stackoverflow	N	659	('the', 'request')
# stackoverflow	N	660	('iterate',)
# stackoverflow	N	661	('developing',)
# stackoverflow	N	662	('but', 'you')
# stackoverflow	N	663	('found', 'out', 'that', 'i')
# stackoverflow	N	664	('things',)
# stackoverflow	N	665	('compiled',)
# stackoverflow	N	666	('at', 'the')
# stackoverflow	N	667	('enough',)
# stackoverflow	N	668	('album',)
# stackoverflow	N	669	('initialized',)
# stackoverflow	N	670	('expect', 'to')
# stackoverflow	N	671	('code', 'fragment', 'for')
# stackoverflow	N	672	('starting',)
# stackoverflow	N	673	('this', 'library')
# stackoverflow	N	674	('based', 'on', 'the')
# stackoverflow	N	675	('ways',)
# stackoverflow	N	676	('to', 'include')
# stackoverflow	N	677	('attached', 'to')
# stackoverflow	N	678	('for', 'example')
# stackoverflow	N	679	('to', 'file')
# stackoverflow	N	680	('easy',)
# stackoverflow	N	681	('then', 'updatebar', 'will', 'be', 'called')
# stackoverflow	N	682	('written',)
# stackoverflow	N	683	('level',)
# stackoverflow	N	684	('basically',)
# stackoverflow	N	685	('like',)
# stackoverflow	N	686	('the', 'above')
# stackoverflow	N	687	('will', 'be')
# stackoverflow	N	688	('even',)
# stackoverflow	N	689	('json',)
# stackoverflow	N	690	('file', 'as')
# stackoverflow	N	691	('the', 'name', 'of', 'the')
# stackoverflow	N	692	('code', 'fragment', 'as')
# stackoverflow	N	693	('must',)
# stackoverflow	N	694	('the', 'component')
# stackoverflow	N	695	('achieve',)
# stackoverflow	N	696	('names',)
# stackoverflow	N	697	('i', 'have', 'to')
# stackoverflow	N	698	('adds',)
# stackoverflow	N	699	('src',)
# stackoverflow	N	700	('see', 'if')
# stackoverflow	N	701	('methods',)
# stackoverflow	N	702	('will', 'take', 'care', 'of', 'the')
# stackoverflow	N	703	('located',)
# stackoverflow	N	704	('s', 'parent')
# stackoverflow	N	705	('thrown',)
# stackoverflow	N	706	('that', 'will')
# stackoverflow	N	707	('yahoo',)
# stackoverflow	N	708	('return', 'an', 'instance', 'of')
# stackoverflow	N	709	('libraries',)
# stackoverflow	N	710	('here', 's')
# stackoverflow	N	711	('line',)
# stackoverflow	N	712	('found', 'that')
# stackoverflow	N	713	('the', 'file', 'name', 'but', 'i')
# stackoverflow	N	714	('that', 'you', 'need')
# stackoverflow	N	715	('code', 'fragment', 'should')
# stackoverflow	N	716	('unique',)
# stackoverflow	N	717	('root', 'value')
# stackoverflow	N	718	('work',)
# stackoverflow	N	719	('file', 'name')
# stackoverflow	N	720	('point',)
# stackoverflow	N	721	('the', 'code', 'fragment', 'and')
# stackoverflow	N	722	('a', 'code', 'fragment', 'and')
# stackoverflow	N	723	('the', 'service')
# stackoverflow	N	724	('tip',)
# stackoverflow	N	725	('was',)
# stackoverflow	N	726	('this', 'api')
# stackoverflow	N	727	('filled', 'by')
# stackoverflow	N	728	('graphics',)
# stackoverflow	N	729	('the', 'stream')
# stackoverflow	N	730	('me',)
# stackoverflow	N	731	('kind', 'of')
# stackoverflow	N	732	('out', 'that')
# stackoverflow	N	733	('note',)
# stackoverflow	N	734	('jdbc',)
# stackoverflow	N	735	('be', 'called')
# stackoverflow	N	736	('location',)
# stackoverflow	N	737	('code', 'fragment', 'for', 'that')
# stackoverflow	N	738	('getter',)
# stackoverflow	N	739	('main',)
# stackoverflow	N	740	('to', 'add')
# stackoverflow	N	741	('dependency', 'to')
# stackoverflow	N	742	('keep',)
# stackoverflow	N	743	('variables',)
# stackoverflow	N	744	('xml',)
# stackoverflow	N	745	('the', 'desired')
# stackoverflow	N	746	('currently',)
# stackoverflow	N	747	('what',)
# stackoverflow	N	748	('file', 's')
# stackoverflow	N	749	('to', 'use', 'a')
# stackoverflow	N	750	('this', 'answer')
# stackoverflow	N	751	('paths',)
# stackoverflow	N	752	('message', 'is')
# stackoverflow	N	753	('jna',)
# stackoverflow	N	754	('a', 'static')
# stackoverflow	N	755	('around',)
# stackoverflow	N	756	('classpath', 'in')
# stackoverflow	N	757	('can', 'also')
# stackoverflow	N	758	('until',)
# stackoverflow	N	759	('vs',)
# stackoverflow	N	760	('it', 'from')
# stackoverflow	N	761	('from', 'a')
# stackoverflow	N	762	('a', 'code', 'fragment', 'you', 'can')
# stackoverflow	N	763	('5',)
# stackoverflow	N	764	('want',)
# stackoverflow	N	765	('the', 'build')
# stackoverflow	N	766	('lists', 'several')
# stackoverflow	N	767	('a', 'regex')
# stackoverflow	N	768	('data', 'from')
# stackoverflow	N	769	('in', 'memory')
# stackoverflow	N	770	('also', 'tried')
# stackoverflow	N	771	('allow',)
# stackoverflow	N	772	('if', 'you', 'use')
# stackoverflow	N	773	('that', 's')
# stackoverflow	N	774	('and', 'a')
# stackoverflow	N	775	('code', 'fragment', 'has')
# stackoverflow	N	776	('complete',)
# stackoverflow	N	777	('character',)
# stackoverflow	N	778	('why', 'it')
# stackoverflow	N	779	('being',)
# stackoverflow	N	780	('should', 'have', 'been')
# stackoverflow	N	781	('to', 'file', 'name')
# stackoverflow	N	782	('to', 'create', 'an')
# stackoverflow	N	783	('check', 'the', 'return')
# stackoverflow	N	784	('and', 'all')
# stackoverflow	N	785	('curious',)
# stackoverflow	N	786	('should', 'be')
# stackoverflow	N	787	('custom',)
# stackoverflow	N	788	('30',)
# stackoverflow	N	789	('full',)
# stackoverflow	N	790	('use',)
# stackoverflow	N	791	('jpa', 'number')
# stackoverflow	N	792	('your', 'manifest')
# stackoverflow	N	793	('hour',)
# stackoverflow	N	794	('on', 'a')
# stackoverflow	N	795	('why', 'not')
# stackoverflow	N	796	('default', 'code', 'fragment')
# stackoverflow	N	797	('do', 'a')
# stackoverflow	N	798	('app', 'page')
# stackoverflow	N	799	('is', 'called')
# stackoverflow	N	800	('please', 'help', 'me')
# stackoverflow	N	801	('to', 'avoid')
# stackoverflow	N	802	('do', 'that')
# stackoverflow	N	803	('is', 'just')
# stackoverflow	N	804	('accordingly',)
# stackoverflow	N	805	('filter',)
# stackoverflow	N	806	('tab',)
# stackoverflow	N	807	('the', 'size')
# stackoverflow	N	808	('but', 'this')
# stackoverflow	N	809	('model',)
# stackoverflow	N	810	('i', 'want', 'this')
# stackoverflow	N	811	('to', 'do')
# stackoverflow	N	812	('a', 'resolution')
# stackoverflow	N	813	('classpath',)
# stackoverflow	N	814	('using', 'it')
# stackoverflow	N	815	('pattern',)
# stackoverflow	N	816	('via',)
# stackoverflow	N	817	('initialization',)
# stackoverflow	N	818	('proxy',)
# stackoverflow	N	819	('mangoes',)
# stackoverflow	N	820	('you', 'want', 'to')
# stackoverflow	N	821	('select', 'which', 'function', 'is', 'to', 'be', 'called')
# stackoverflow	N	822	('there', 'are', 'any')
# stackoverflow	N	823	('3', 'hours')
# stackoverflow	N	824	('method', 'should')
# stackoverflow	N	825	('accept',)
# stackoverflow	N	826	('coming',)
# stackoverflow	N	827	('creating', 'new', 'rules')
# stackoverflow	N	828	('referenced',)
# stackoverflow	N	829	('java', 'se')
# stackoverflow	N	830	('original',)
# stackoverflow	N	831	('been', 'requested')
# stackoverflow	N	832	('also',)
# stackoverflow	N	833	('no', 'problem')
# stackoverflow	N	834	('this', 'as')
# stackoverflow	N	835	('configured', 'in')
# stackoverflow	N	836	('break',)
# stackoverflow	N	837	('the', 'root')
# stackoverflow	N	838	('posted',)
# stackoverflow	N	839	('char',)
# stackoverflow	N	840	('on', 'the')
# stackoverflow	N	841	('i', 'have')
# stackoverflow	N	842	('code', 'fragment', 'is', 'a')
# stackoverflow	N	843	('type', 'code')
# stackoverflow	N	844	('i', 'ca')
# stackoverflow	N	845	('created', 'a')
# stackoverflow	N	846	('ca', 'n', 't')
# stackoverflow	N	847	('including',)
# stackoverflow	N	848	('central',)
# stackoverflow	N	849	('lot',)
# stackoverflow	N	850	('no',)
# stackoverflow	N	851	('api', 'name', 'and')
# stackoverflow	N	852	('leave',)
# stackoverflow	N	853	('netbeans',)
# stackoverflow	N	854	('contains', 'a')
# stackoverflow	N	855	('the', 'string')
# stackoverflow	N	856	('nt',)
# stackoverflow	N	857	('text',)
# stackoverflow	N	858	('open',)
# stackoverflow	N	859	('access',)
# stackoverflow	N	860	('but', 'it')
# stackoverflow	N	861	('root',)
# stackoverflow	N	862	('name', 'file')
# stackoverflow	N	863	('it',)
# stackoverflow	N	864	('spring',)
# stackoverflow	N	865	('you', 'should', 'be')
# stackoverflow	N	866	('particular',)
# stackoverflow	N	867	('path', 'from')
# stackoverflow	N	868	('built',)
# stackoverflow	N	869	('objectmapper',)
# stackoverflow	N	870	('exported',)
# stackoverflow	N	871	('out', 'the')
# stackoverflow	N	872	('send',)
# stackoverflow	N	873	('might',)
# stackoverflow	N	874	('garbage', 'collector')
# stackoverflow	N	875	('constructor',)
# stackoverflow	N	876	('that', 'is')
# stackoverflow	N	877	('wait',)
# stackoverflow	N	878	('data',)
# stackoverflow	N	879	('java',)
# stackoverflow	N	880	('the', 'value', 'of')
# stackoverflow	N	881	('equivalent',)
# stackoverflow	N	882	('all',)
# stackoverflow	N	883	('code', 'fragment', 'method')
# stackoverflow	N	884	('ftpserver',)
# stackoverflow	N	885	('dsn',)
# stackoverflow	N	886	('either',)
# stackoverflow	N	887	('android',)
# stackoverflow	N	888	('stop',)
# stackoverflow	N	889	('use', 'code', 'fragment')
# stackoverflow	N	890	('neo4j',)
# stackoverflow	N	891	('see', 'some')
# stackoverflow	N	892	('you', 'also')
# stackoverflow	N	893	('about', 'this')
# stackoverflow	N	894	('scoped',)
# stackoverflow	N	895	('lines', 'and')
# stackoverflow	N	896	('use', 'a', 'code', 'fragment')
# stackoverflow	N	897	('we', 'have', 'a')
# stackoverflow	N	898	('remove',)
# stackoverflow	N	899	('name', 'instead', 'of')
# stackoverflow	N	900	('the', 'database')
# stackoverflow	N	901	('in', 'the', 'code', 'fragment')
# stackoverflow	N	902	('put', 'your')
# stackoverflow	N	903	('external',)
# stackoverflow	N	904	('not', 'get')
# stackoverflow	N	905	('you', 're')
# stackoverflow	N	906	('users',)
# stackoverflow	N	907	('shows',)
# stackoverflow	N	908	('line', 'number')
# stackoverflow	N	909	('tomcat',)
# stackoverflow	N	910	('runnable',)
# stackoverflow	N	911	('code', 'fragment')
# stackoverflow	N	912	('are', 'one')
# stackoverflow	N	913	('know',)
# stackoverflow	N	914	('method', 'of')
# stackoverflow	N	915	('because',)
# stackoverflow	N	916	('did', 'n', 't')
# stackoverflow	N	917	('outputs', 'of')
# stackoverflow	N	918	('up', 'to', 'you', 'to')
# stackoverflow	N	919	('in', 'an')
# stackoverflow	N	920	('in', 'combination', 'with')
# stackoverflow	N	921	('day',)
# stackoverflow	N	922	('invoke',)
# stackoverflow	N	923	('headers',)
# stackoverflow	N	924	('there', 'is')
# stackoverflow	N	925	('an', 'example')
# stackoverflow	N	926	('than', '5', 'hobbies')
# stackoverflow	N	927	('i', 'see', 'the')
# stackoverflow	N	928	('loop',)
# stackoverflow	N	929	('means', 'that', 'if', 'you')
# stackoverflow	N	930	('match',)
# stackoverflow	N	931	('above',)
# stackoverflow	N	932	('to', 'display')
# stackoverflow	N	933	('is', 'code', 'fragment')
# stackoverflow	N	934	('re',)
# stackoverflow	N	935	('of', 'the', 'code', 'fragment')
# stackoverflow	N	936	('but', 'i')
# stackoverflow	N	937	('gets',)
# stackoverflow	N	938	('url',)
# stackoverflow	N	939	('user',)
# stackoverflow	N	940	('you', 'can', 'get')
# stackoverflow	N	941	('map',)
# stackoverflow	N	942	('now', 'i')
# stackoverflow	N	943	('to', 'send', 'a')
# stackoverflow	N	944	('have',)
# stackoverflow	N	945	('is', 'my', 'code')
# stackoverflow	N	946	('which', 'you')
# stackoverflow	N	947	('to', 'the', 'code')
# stackoverflow	N	948	('added',)
# stackoverflow	N	949	('instance', 'variable')
# stackoverflow	N	950	('new', 'object')
# stackoverflow	N	951	('return',)
# stackoverflow	N	952	('form',)
# stackoverflow	N	953	('github',)
# stackoverflow	N	954	('explicitly',)
# stackoverflow	N	955	('e', 'g', 'code', 'fragment')
# stackoverflow	N	956	('key',)
# stackoverflow	N	957	('dependencies', 'including')
# stackoverflow	N	958	('component',)
# stackoverflow	N	959	('now', 'in')
# stackoverflow	N	960	('reading',)
# stackoverflow	N	961	('code', 'fragment', 'by')
# stackoverflow	N	962	('in', 'the', 'java')
# stackoverflow	N	963	('but', 'not')
# stackoverflow	N	964	('expect',)
# stackoverflow	N	965	('please', 'see', 'the')
# stackoverflow	N	966	('project', 'in')
# stackoverflow	N	967	('do', 'n', 't', 'you')
# stackoverflow	N	968	('better', 'way')
# stackoverflow	N	969	('jre',)
# stackoverflow	N	970	('using', 'the')
# stackoverflow	N	971	('logcat',)
# stackoverflow	N	972	('your',)
# stackoverflow	N	973	('you', 'can', 'try')
# stackoverflow	N	974	('i', 'want', 'to')
# stackoverflow	N	975	('logic',)
# stackoverflow	N	976	('path',)
# stackoverflow	N	977	('the', 'code', 'fragment', 'and', 'code', 'fragment')
# stackoverflow	N	978	('packages',)
# stackoverflow	N	979	('encoding',)
# stackoverflow	N	980	('web', 'application')
# stackoverflow	N	981	('generally',)
# stackoverflow	N	982	('available', 'to')
# stackoverflow	N	983	('node',)
# stackoverflow	N	984	('without',)
# stackoverflow	N	985	('future',)
# stackoverflow	N	986	('available', 'which')
# stackoverflow	N	987	('before',)
# stackoverflow	N	988	('and', 'you', 'should')
# stackoverflow	N	989	('ca',)
# stackoverflow	N	990	('of', 'this')
# stackoverflow	N	991	('you', 'can', 'see')
# stackoverflow	N	992	('does', 'it')
# stackoverflow	N	993	('from', 'eclipse')
# stackoverflow	N	994	('get', 'an')
# stackoverflow	N	995	('found', 'out', 'that')
# stackoverflow	N	996	('i', 'have', 'found')
# stackoverflow	N	997	('best', 'practices')
# stackoverflow	N	998	('if', 'i', 'have')
# stackoverflow	N	999	('get',)
# stackoverflow	N	1000	('setter',)
# stackoverflow	-	1	('proxy',)
# stackoverflow	-	2	('wrote',)
# stackoverflow	-	3	('the', 'file', 'name')
# stackoverflow	-	4	('run',)
# stackoverflow	-	5	('drl',)
# stackoverflow	-	6	('possible',)
# stackoverflow	-	7	('correct',)
# stackoverflow	-	8	('ran',)
# stackoverflow	-	9	('translucent',)
# stackoverflow	-	10	('rather',)
# stackoverflow	-	11	('saving',)
# stackoverflow	-	12	('jpa', 'hibernate')
# stackoverflow	-	13	('guess',)
# stackoverflow	-	14	('now',)
# stackoverflow	-	15	('part',)
# stackoverflow	-	16	('tool',)
# stackoverflow	-	17	('cglib',)
# stackoverflow	-	18	('may', 'not')
# stackoverflow	-	19	('solution',)
# stackoverflow	-	20	('n',)
# stackoverflow	-	21	('sort',)
# stackoverflow	-	22	('must', 'be')
# stackoverflow	-	23	('except',)
# stackoverflow	-	24	('possible', 'to')
# stackoverflow	-	25	('wrong',)
# stackoverflow	-	26	('token', 'and')
# stackoverflow	-	27	('may',)
# stackoverflow	-	28	('processing',)
# stackoverflow	-	29	('me',)
# stackoverflow	-	30	('showing',)
# stackoverflow	-	31	('it', 'did', 'n', 't')
# stackoverflow	-	32	('native',)
# stackoverflow	-	33	('source',)
# stackoverflow	-	34	('out', 'how')
# stackoverflow	-	35	('fail',)
# stackoverflow	-	36	('ca', 'n', 't')
# stackoverflow	-	37	('or',)
# stackoverflow	-	38	('good',)
# stackoverflow	-	39	('jna',)
# stackoverflow	-	40	('read',)
# stackoverflow	-	41	('example',)
# stackoverflow	-	42	('need', 'to', 'be')
# stackoverflow	-	43	('a', 'weird')
# stackoverflow	-	44	('correctly',)
# stackoverflow	-	45	('in',)
# stackoverflow	-	46	('give',)
# stackoverflow	-	47	('created',)
# stackoverflow	-	48	('something', 'like')
# stackoverflow	-	49	('if', 'i')
# stackoverflow	-	50	('into',)
# stackoverflow	-	51	('call',)
# stackoverflow	-	52	('which',)
# stackoverflow	-	53	('really',)
# stackoverflow	-	54	('xml',)
# stackoverflow	-	55	('properly',)
# stackoverflow	-	56	('i', 'was')
# stackoverflow	-	57	('the', 'response')
# stackoverflow	-	58	('it', 'says')
# stackoverflow	-	59	('were',)
# stackoverflow	-	60	('about',)
# stackoverflow	-	61	('spring',)
# stackoverflow	-	62	('api', 'name')
# stackoverflow	-	63	('by', 'the')
# stackoverflow	-	64	('i', 'have')
# stackoverflow	-	65	('i', 've')
# stackoverflow	-	66	('ve',)
# stackoverflow	-	67	('is', 'an')
# stackoverflow	-	68	('just',)
# stackoverflow	-	69	('seems',)
# stackoverflow	-	70	('files',)
# stackoverflow	-	71	('figuring', 'out')
# stackoverflow	-	72	('think',)
# stackoverflow	-	73	('has',)
# stackoverflow	-	74	('from',)
# stackoverflow	-	75	('should',)
# stackoverflow	-	76	('these',)
# stackoverflow	-	77	('but',)
# stackoverflow	-	78	('eclipse',)
# stackoverflow	-	79	('trying', 'to')
# stackoverflow	-	80	('i', 'd')
# stackoverflow	-	81	('very',)
# stackoverflow	-	82	('gives', 'the')
# stackoverflow	-	83	('not', 'found')
# stackoverflow	-	84	('at',)
# stackoverflow	-	85	('project',)
# stackoverflow	-	86	('i', 'am', 'not', 'sure')
# stackoverflow	-	87	('since',)
# stackoverflow	-	88	('information',)
# stackoverflow	-	89	('myself',)
# stackoverflow	-	90	('there', 'are')
# stackoverflow	-	91	('might', 'not')
# stackoverflow	-	92	('complicated',)
# stackoverflow	-	93	('between',)
# stackoverflow	-	94	('i', 'do', 'n', 't', 'understand')
# stackoverflow	-	95	('little',)
# stackoverflow	-	96	('this', 'is')
# stackoverflow	-	97	('because',)
# stackoverflow	-	98	('warning',)
# stackoverflow	-	99	('the', 'above', 'code')
# stackoverflow	-	100	('understand',)
# stackoverflow	-	101	('following',)
# stackoverflow	-	102	('messages',)
# stackoverflow	-	103	('i', 'added')
# ...
# appreviews	-	351	('original',)
# appreviews	-	352	('because',)
# appreviews	-	353	('great', 'app')
# appreviews	-	354	('galaxy', 's3')
# appreviews	-	355	('each',)
# appreviews	-	356	('i', 'want', 'to')
# appreviews	-	357	('give',)
# appreviews	-	358	('i', 'get', 'an', 'error')
# appreviews	-	359	('facebook', 'when', 'i')
# appreviews	-	360	('try', 'to')
# appreviews	-	361	('samsung', 'galaxy')
# appreviews	-	362	('use',)
# appreviews	-	363	('n', 't', 'been')
# appreviews	-	364	('off', 'the')
# appreviews	-	365	('please', 'fix')
# appreviews	-	366	('htc', 'one')
# appreviews	-	367	('out', 'of')
# appreviews	-	368	('when', 'you')
# appreviews	-	369	('black',)
# appreviews	-	370	('if',)
# appreviews	-	371	('im',)
# appreviews	-	372	('this', 'app', 'is')
# appreviews	-	373	('heads', 'up', 'feature')
# appreviews	-	374	('really',)
# appreviews	-	375	('the', 'app', 'freezes')
# appreviews	-	376	('crap',)
# appreviews	-	377	('able', 'to')
# appreviews	-	378	('see',)
# appreviews	-	379	('download',)
# appreviews	-	380	('always', 'freezes')
# appreviews	-	381	('stops',)
# appreviews	-	382	('needs',)
# appreviews	-	383	('important',)
# appreviews	-	384	('number',)
# appreviews	-	385	('alot',)
# appreviews	-	386	('everyone',)
# appreviews	-	387	('now', 'it')
# appreviews	-	388	('about', '2', '3', 'of', 'the', 'screen')
# appreviews	-	389	('get',)
# appreviews	-	390	('now', 'it', 'freezes')
# appreviews	-	391	('about', '2')
# appreviews	-	392	('sooo',)
# appreviews	-	393	('but', 'since')
# appreviews	-	394	('but', 'the')
# appreviews	-	395	('chat',)
# appreviews	-	396	('have', 'a')
# appreviews	-	397	('longer',)
# appreviews	-	398	('have',)
# appreviews	-	399	('else',)
# appreviews	-	400	('edit',)
# appreviews	-	401	('white',)
# appreviews	-	402	('being', 'able', 'to')
# appreviews	-	403	('white', 'screen')
# appreviews	-	404	('ok',)
# appreviews	-	405	('but', 'sometimes')
# appreviews	-	406	('but', 'now')
# appreviews	-	407	('also',)
# appreviews	-	408	('but', 'it', 'freezes')
# appreviews	-	409	('but', 'sometimes', 'it')
# appreviews	-	410	('record', 'the')
# appreviews	-	411	('gt',)
# appreviews	-	412	('messages',)
# appreviews	-	413	('battery', 'life')
# appreviews	-	414	('battery',)
# appreviews	-	415	('back',)
# appreviews	-	416	('back', 'to', 'the')
# appreviews	-	417	('connect',)
# appreviews	-	418	('connect', 'please')
# appreviews	-	419	('but', 'now', 'it')
# appreviews	-	420	('but', 'freezes')
# appreviews	-	421	('only',)
# appreviews	-	422	('play',)
# appreviews	-	423	('only', 'works')
# appreviews	-	424	('first',)
# appreviews	-	425	('always',)
# appreviews	-	426	('awesome',)
# appreviews	-	427	('any',)
# appreviews	-	428	('pretty',)
# appreviews	-	429	('but', 'i')
# appreviews	-	430	('was', 'fine')
# appreviews	-	431	('display',)
# appreviews	-	432	('but', 'it')
# appreviews	-	433	('out',)
# appreviews	-	434	('latest',)
# appreviews	-	435	('leave', 'the')
# appreviews	-	436	('version',)
# appreviews	-	437	('otherwise',)
# appreviews	-	438	('do', 'n', 't', 'know', 'how')
# appreviews	-	439	('mission',)
# appreviews	-	440	('locks', 'up')
# appreviews	-	441	('and', 'i')
# appreviews	-	442	('and', 'this')
# appreviews	-	443	('and', 'now')
# appreviews	-	444	('and', 'it', 's')
# appreviews	-	445	('and', 'it')
# appreviews	-	446	('and', 'does')
# appreviews	-	447	('and', 'the')
# appreviews	-	448	('are', 'a')
# appreviews	-	449	('and', 'can')
# appreviews	-	450	('notifications',)
# appreviews	-	451	('and', 'a')
# appreviews	-	452	('and', 'you')
# appreviews	-	453	('htc',)
# appreviews	-	454	('on', 'the')
# appreviews	-	455	('and', 'u')
# appreviews	-	456	('and', 'new')
# appreviews	-	457	('and', 'only')
# appreviews	-	458	('and', 'ill')
# appreviews	-	459	('wanted', 'to')
# appreviews	-	460	('continue',)
# appreviews	-	461	('to', 'the')
# appreviews	-	462	('to', 'uninstall')
# appreviews	-	463	('to', 'your')
# appreviews	-	464	('to', 'give')
# appreviews	-	465	('lack', 'of')
# appreviews	-	466	('to', 'open')
# appreviews	-	467	('on',)
# appreviews	-	468	('on', 'my', 'galaxy', 's4')
# appreviews	-	469	('all',)
# appreviews	-	470	('i', 'will')
# appreviews	-	471	('i', 'like')
# appreviews	-	472	('i', 'm', 'on')
# appreviews	-	473	('i', 'do', 'n', 't')
# appreviews	-	474	('i', 'do')
# appreviews	-	475	('i', 'use')
# appreviews	-	476	('i', 'really')
# appreviews	-	477	('i', 'ca', 'n', 't')
# appreviews	-	478	('i', 'ca', 'nt')
# appreviews	-	479	('i', 'ca')
# appreviews	-	480	('i', 've', 'tried')
# appreviews	-	481	('i', 've')
# appreviews	-	482	('i', 'love', 'it')
# appreviews	-	483	('i', 'have', 'to')
# appreviews	-	484	('slow', 'app')
# appreviews	-	485	('i', 'have')
# appreviews	-	486	('i', 'll')
# appreviews	-	487	('i', 'am')
# appreviews	-	488	('search',)
# appreviews	-	489	('i', 'miss')
# appreviews	-	490	('i',)
# appreviews	-	491	('my', 'phone')
# appreviews	-	492	('my', 'galaxy')
# appreviews	-	493	('phone', 'is')
# appreviews	-	494	('phone',)
# appreviews	-	495	('on', 'my', 'phone')
# appreviews	-	496	('on', 'my', 'samsung')
# appreviews	-	497	('than',)
# appreviews	-	498	('to', 'be')
# appreviews	-	499	('to', 'log', 'in')
# appreviews	-	500	('perfectly',)
# appreviews	-	501	('old',)
# appreviews	-	502	('app', 'but')
# appreviews	-	503	('maps',)
# appreviews	-	504	('text',)
# appreviews	-	505	('app', 'for')
# appreviews	-	506	('why',)
# appreviews	-	507	('which',)
# appreviews	-	508	('app', 'is')
# appreviews	-	509	('app',)
# appreviews	-	510	('error',)
# appreviews	-	511	('take',)
# appreviews	-	512	('pics',)
# appreviews	-	513	('s',)
# appreviews	-	514	('bye',)
# appreviews	-	515	('video',)
# appreviews	-	516	('all', 'this', 'app')
# appreviews	-	517	('fails', 'to')
# appreviews	-	518	('galaxy', 's4')
# appreviews	-	519	('all', 'the', 'time')
# appreviews	-	520	('into', 'the')
# appreviews	-	521	('requested',)
# appreviews	-	522	('lives',)
# appreviews	-	523	('problem',)
# appreviews	-	524	('send',)
# appreviews	-	525	('upgrade',)
# appreviews	-	526	('all', 'in', 'all')
# appreviews	-	527	('app', 'and')
# appreviews	-	528	('guys',)
# appreviews	-	529	('this',)
# appreviews	-	530	('rain',)
# appreviews	-	531	('to', 'facebook')
# appreviews	-	532	('terrible',)
# appreviews	-	533	('to', 'get')
# appreviews	-	534	('rate', '5')
# appreviews	-	535	('to', 'play')
# appreviews	-	536	('to', 'see', 'the')
# appreviews	-	537	('to', 'see')
# appreviews	-	538	('to', 'connect')
# appreviews	-	539	('wifi',)
# appreviews	-	540	('to', 'load')
# appreviews	-	541	('page',)
# appreviews	-	542	('to', 'upload')
# appreviews	-	543	('to', 'sign', 'in', 'with', 'facebook')
# appreviews	-	544	('to', 'sign')
# appreviews	-	545	('to',)
# appreviews	-	546	('3', 'and')
# appreviews	-	547	('how',)
# appreviews	-	548	('touch',)
# appreviews	-	549	('this', 'app')
# appreviews	-	550	('sign', 'in')
# appreviews	-	551	('this', 'is', 'a')
# appreviews	-	552	('this', 'is')
# appreviews	-	553	('either',)
# appreviews	-	554	('this', 'game', 'but')
# appreviews	-	555	('this', 'game')
# appreviews	-	556	('bad',)
# appreviews	-	557	('facebook', 'the')
# appreviews	-	558	('stop',)
# appreviews	-	559	('s2',)
# appreviews	-	560	('failed',)
# appreviews	-	561	('fix', 'the', 'bug')
# appreviews	-	562	('your',)
# appreviews	-	563	('connection',)
# appreviews	-	564	('is', 'n', 't')
# appreviews	-	565	('is', 'an')
# appreviews	-	566	('is', 'really')
# appreviews	-	567	('is', 'a')
# appreviews	-	568	('is', 'still')
# appreviews	-	569	('is', 'no')
# appreviews	-	570	('working',)
# appreviews	-	571	('please', 'fix', 'this', 'problem')
# appreviews	-	572	('please', 'fix', 'this')
# appreviews	-	573	('please', 'fix', 'it')
# appreviews	-	574	('please', 'try', 'again')
# appreviews	-	575	('loading',)
# appreviews	-	576	('that',)
# appreviews	-	577	('fix', 'the')
# appreviews	-	578	('update', 'since')
# appreviews	-	579	('cool',)
# appreviews	-	580	('network',)
# appreviews	-	581	('fix',)
# appreviews	-	582	('an', 'error')
# appreviews	-	583	('update', 'i')
# appreviews	-	584	('update', 'please', 'fix')
# appreviews	-	585	('update',)
# appreviews	-	586	('that', 's')
# appreviews	-	587	('pack',)
# appreviews	-	588	('can', 'not')
# appreviews	-	589	('can',)
# appreviews	-	590	('not', 'for')
# appreviews	-	591	('not', 'open')
# appreviews	-	592	('not',)
# appreviews	-	593	('please', 'try')
# appreviews	-	594	('thanks',)
# appreviews	-	595	('fix', 'this')
# appreviews	-	596	('a', 'lot')
# appreviews	-	597	('as', 'soon', 'as')
# appreviews	-	598	('as',)
# appreviews	-	599	('a', 'good', 'game')
# appreviews	-	600	('pls', 'fix')
# appreviews	-	601	('a', 'black')
# appreviews	-	602	('a', 'big')
# appreviews	-	603	('a', 'mission')
# appreviews	-	604	('good',)
# appreviews	-	605	('pls', 'fix', 'this')
# appreviews	-	606	('a', 'few')
# appreviews	-	607	('a',)
# appreviews	-	608	('used', 'to')
# appreviews	-	609	('anything',)
# appreviews	-	610	('it', 'suck', 'monkey', 'ball', 'it')
# appreviews	-	611	('fix', 'my')
# appreviews	-	612	('good', 'but')
# appreviews	-	613	('fix', 'this', 'problem')
# appreviews	-	614	('force',)
# appreviews	-	615	('pictures',)
# appreviews	-	616	('want',)
# appreviews	-	617	('then', 'i')
# appreviews	-	618	('then', 'it', 'freezes')
# appreviews	-	619	('then', 'it')
# appreviews	-	620	('then',)
# appreviews	-	621	('close',)
# appreviews	-	622	('good', 'app')
# appreviews	-	623	('bug', 'please')
# appreviews	-	624	('use', 'the')
# appreviews	-	625	('widget',)
# appreviews	-	626	('screen', 'i')
# appreviews	-	627	('screen',)
# appreviews	-	628	('really', 'good')
# appreviews	-	629	('so',)
# appreviews	-	630	('so', 'many')
# appreviews	-	631	('so', 'i')
# appreviews	-	632	('just',)
# appreviews	-	633	('does',)
# appreviews	-	634	('n', 't', 'open')
# appreviews	-	635	('n', 't', 'work')
# appreviews	-	636	('n', 't')
# appreviews	-	637	('t',)
# appreviews	-	638	('just', 'freezes')
# appreviews	-	639	('updated',)
# appreviews	-	640	('does', 'n', 't')
# appreviews	-	641	('freezes', 'and')
# appreviews	-	642	('freezes', 'or')
# appreviews	-	643	('freezes', 'up', 'and')
# appreviews	-	644	('issue',)
# appreviews	-	645	('freezes', 'every', 'time')
# appreviews	-	646	('freezes', 'when', 'browser', 'loads')
# appreviews	-	647	('does', 'not')
# appreviews	-	648	('times',)
# appreviews	-	649	('freezes', 'alot')
# appreviews	-	650	('for',)
# appreviews	-	651	('do', 'not')
# appreviews	-	652	('do', 'anything')
# appreviews	-	653	('do', 'nt')
# appreviews	-	654	('do',)
# appreviews	-	655	('for', 'it')
# appreviews	-	656	('for', 'the')
# appreviews	-	657	('2',)
# appreviews	-	658	('times', 'it')
# appreviews	-	659	('nice',)
# appreviews	-	660	('clean',)
# appreviews	-	661	('sometimes',)
# appreviews	-	662	('works', 'but')
# appreviews	-	663	('works',)
# appreviews	-	664	('other',)
# appreviews	-	665	('freezes', 'when')
# appreviews	-	666	('freezes', 'constantly')
# appreviews	-	667	('issue', 'and')
# appreviews	-	668	('the', 'option')
# appreviews	-	669	('the', 'product')
# appreviews	-	670	('the', 'main')
# appreviews	-	671	('the', 'lack', 'of')
# appreviews	-	672	('the', 'original')
# appreviews	-	673	('the', 'second')
# appreviews	-	674	('the', 'option', 'to')
# appreviews	-	675	('the', 'store')
# appreviews	-	676	('the', 'new')
# appreviews	-	677	('the', 'keyboard')
# appreviews	-	678	('the', 'blue')
# appreviews	-	679	('the',)
# appreviews	-	680	('time', 'i')
# appreviews	-	681	('time', 'to')
# appreviews	-	682	('time', 'is')
# appreviews	-	683	('the', 'background')
# appreviews	-	684	('the', 'facebook', 'icon')
# appreviews	-	685	('freezes',)
# appreviews	-	686	('the', 'time')
# appreviews	-	687	('the', 'phone')
# appreviews	-	688	('the', 'app', 'and')
# appreviews	-	689	('the', 'app', 'is')
# appreviews	-	690	('the', 'app', 'again')
# appreviews	-	691	('the', 'app')
# appreviews	-	692	('the', 'issue')
# appreviews	-	693	('the', 'bug')
# appreviews	-	694	('the', 'application')
# appreviews	-	695	('the', 'screen', 'freezes')
# appreviews	-	696	('the', 'screen')
# appreviews	-	697	('the', 'system')
# appreviews	-	698	('the', 'features')
# appreviews	-	699	('the', 'game', 'is')
# appreviews	-	700	('the', 'game')
# appreviews	-	701	('if', 'the')
# appreviews	-	702	('it', 'was')
# appreviews	-	703	('you', 'will')
# appreviews	-	704	('application',)
# appreviews	-	705	('game', 'freezes')
# appreviews	-	706	('game', 'is')
# appreviews	-	707	('it', 'but')
# appreviews	-	708	('it', 's')
# appreviews	-	709	('be', 'a')
# appreviews	-	710	('be', 'fixed')
# appreviews	-	711	('full',)
# appreviews	-	712	('game', 'but')
# appreviews	-	713	('at', 'the')
# appreviews	-	714	('plz',)
# appreviews	-	715	('it', 'and')
# appreviews	-	716	('log', 'in')
# appreviews	-	717	('in', 'my')
# appreviews	-	718	('in', 'and')
# appreviews	-	719	('game', 'it')
# appreviews	-	720	('game', 'but', 'it')
# appreviews	-	721	('it', 'on')
# appreviews	-	722	('features', 'of')
# appreviews	-	723	('crashing',)
# appreviews	-	724	('work',)
# appreviews	-	725	('going',)
# appreviews	-	726	('go',)
# appreviews	-	727	('launcher',)
# appreviews	-	728	('features', 'and')
# appreviews	-	729	('features',)
# appreviews	-	730	('some',)
# appreviews	-	731	('even', 'after')
# appreviews	-	732	('it', 'works')
# appreviews	-	733	('running', 'in')
# appreviews	-	734	('sorry',)
# appreviews	-	735	('some', 'times', 'it')
# appreviews	-	736	('it', 'it')
# appreviews	-	737	('in', 'this')
# appreviews	-	738	('in', 'the')
# appreviews	-	739	('did',)
# appreviews	-	740	('will', 'have', 'to')
# appreviews	-	741	('love', 'this', 'game', 'but')
# appreviews	-	742	('love', 'this', 'game')
# appreviews	-	743	('love', 'this')
# appreviews	-	744	('love', 'the')
# appreviews	-	745	('will', 'not')
# appreviews	-	746	('will', 'be')
# appreviews	-	747	('will',)
# appreviews	-	748	('soon',)
# appreviews	-	749	('5', 'stars')
# appreviews	-	750	('5',)
# appreviews	-	751	('star', 'for')
# appreviews	-	752	('star',)
# appreviews	-	753	('fixed',)
# appreviews	-	754	('server',)
# appreviews	-	755	('love', 'to')
# appreviews	-	756	('last',)
# appreviews	-	757	('in', 'mid')
# appreviews	-	758	('when', 'u')
# appreviews	-	759	('in',)
# appreviews	-	760	('me',)
# appreviews	-	761	('facebook',)
# appreviews	-	762	('it', 'i')
# appreviews	-	763	('hate',)
# appreviews	-	764	('when', 'i')
# appreviews	-	765	('when',)
# appreviews	-	766	('now',)
# appreviews	-	767	('super',)
# appreviews	-	768	('hate', 'the')
# appreviews	-	769	('like',)
# appreviews	-	770	('like', 'the')
# appreviews	-	771	('like', 'to')
# appreviews	-	772	('its',)
# appreviews	-	773	('kept',)
# appreviews	-	774	('no',)
# appreviews	-	775	('you', 'have', 'to')
# appreviews	-	776	('samsung', 'galaxy', 's3')
# appreviews	-	777	('ca', 'n', 't', 'install')
# appreviews	-	778	('ca', 'n', 't')
# appreviews	-	779	('ca', 'nt', 'even')
# appreviews	-	780	('ca', 'nt')
# appreviews	-	781	('ca',)
# appreviews	-	782	('install',)
# appreviews	-	783	('samsung',)
# appreviews	-	784	('open', 'the')
# appreviews	-	785	('note',)
# appreviews	-	786	('most',)
# appreviews	-	787	('it', 'freezes')
# appreviews	-	788	('tried', 'to')
# appreviews	-	789	('tried',)
# appreviews	-	790	('lots', 'of')
# appreviews	-	791	('open',)
# appreviews	-	792	('every',)
# appreviews	-	793	('of', 'the', 'time')
# appreviews	-	794	('more',)
# appreviews	-	795	('you', 'have')
# appreviews	-	796	('you',)
# appreviews	-	797	('resolve',)
# appreviews	-	798	('it', 'in')
# appreviews	-	799	('give', 'you')
# appreviews	-	800	('it', 'has')
# appreviews	-	801	('it', 'a')
# appreviews	-	802	('every', 'time')
# appreviews	-	803	('up',)
# appreviews	-	804	('d',)
# appreviews	-	805	('wo', 'n', 't')
# appreviews	-	806	('wo', 'nt')
# appreviews	-	807	('wo',)
# appreviews	-	808	('every', 'time', 'i')
# appreviews	-	809	('of', 'this', 'app')
# appreviews	-	810	('of', 'the', 'game')
# appreviews	-	811	('stopped',)
# appreviews	-	812	('got',)
# appreviews	-	813	('since', 'update', 'the')
# appreviews	-	814	('since',)
# appreviews	-	815	('day', 'of')
# appreviews	-	816	('release',)
# appreviews	-	817	('has',)
# appreviews	-	818	('got', 'it')
# appreviews	-	819	('better',)
# appreviews	-	820	('from', 'gallery')
# appreviews	-	821	('shut',)
# appreviews	-	822	('down',)
# appreviews	-	823	('same',)
# appreviews	-	824	('it', 'freezes', 'all', 'the', 'time')
# appreviews	-	825	('crashed',)
# appreviews	-	826	('it', 'freezes', 'and')
# appreviews	-	827	('from',)
# appreviews	-	828	('from', 'the')
# appreviews	-	829	('of', 'time')
# appreviews	-	830	('while',)
# appreviews	-	831	('of', 'a')
# appreviews	-	832	('of', 'issues')
# appreviews	-	833	('of', 'battery')
# appreviews	-	834	('of', 'any')
# appreviews	-	835	('of',)
# appreviews	-	836	('it', 'freezes', 'alot')
# appreviews	-	837	('issues',)
# appreviews	-	838	('bugs',)
# appreviews	-	839	('with', 'a', 'black')
# appreviews	-	840	('with', 'a')
# appreviews	-	841	('with', 'its', 'lack', 'of')
# appreviews	-	842	('with',)
# appreviews	-	843	('bugs', 'and')
# appreviews	-	844	('bugs', 'with')
# appreviews	-	845	('options',)
